# %%
"""
initiator for SPC pipeline
"""

import yaml
from spc import charts

week = "20250909-20250916"  # modify the date for analysis

with open("spc_config.yaml", "r", encoding="utf-8") as f:
    cfg = yaml.safe_load(f)

charts.run_from_config(week, cfg)
# Out:
# ===== RUNNING PRODUCT: CWHP 1 mm =====
# no data points in the CWHP 1310 PL Avg DCA-3 Hancheng1
# Accumulating 'CWHP 1 mm | CWHP final thickness Hancheng1': current(4) + history(0) = 4/20 points. No chart yet.
#
# --- CWHP Mesa Final Etch Depth Hancheng1 (I-MR SPC) ---
# Mean: 2.037 | Std Dev: 0.034
# USL: 2.200 | LSL: 1.800
# UCL: 2.156 | LCL: 1.917
# Cp: 1.935 | Cpk: 1.581
# Sigma Level (≈ Cpk × 3): 4.742
# Risk Level: Acceptable
# Last Sigma Level: N/A
# Data source: current(22) from 20250909-20250916
# OOC points: None
# --- 5w1.5BH MesaBOEWidth_2in Hancheng1 (I-MR SPC) ---
# Mean: 4.289 | Std Dev: 0.034
# USL: 4.450 | LSL: 4.150
# UCL: 4.444 | LCL: 4.156
# Cp: 1.454 | Cpk: 1.344
# Sigma Level (≈ Cpk × 3): 4.031
# Risk Level: Moderate
# Last Sigma Level: N/A
# Data source: current(34) from 20250909-20250916
# OOC points: None
# ===== RUNNING PRODUCT: 100G EML 475um =====
# no data points in the 100G EML 475um final thickness Hancheng1
# ...
