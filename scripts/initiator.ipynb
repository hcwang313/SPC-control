# %%
"""
SPC update
"""

import yaml
from spc import charts

week = "20251007-20251014"  # modify the date for analysis

with open("spc_config.yaml", "r", encoding="utf-8") as f:
    cfg = yaml.safe_load(f)

charts.run_from_config(week, cfg)

#=========================================================================================================#
"""
ouput a PDF
"""

import datetime
import os

# build today's date string
today = datetime.date.today().strftime("%Y%m%d")  # e.g. 20250917
output_name = f"{today} SPC console"

# target directory
output_dir = r"C:\Users\Hancheng_Wang\Desktop\Hancheng\SPD\Weekly SPC Monitor Report\weekly SPC report"

# run nbconvert with custom output name and directory
# !jupyter nbconvert --to pdf "initiator.ipynb" --output "{output_name}" --output-dir "{output_dir}"
# Out:
# ===== RUNNING PRODUCT: CWHP 1 mm =====
# no data points in the CWHP 1310 PL Avg DCA-3 Hancheng1
# Accumulating 'CWHP 1 mm | CWHP final thickness Hancheng1': current(14) + history(0) = 14/20 points. No chart yet.
#
# --- CWHP Mesa Final Etch Depth Hancheng1 (I-MR SPC) ---
# Mean: 2.049 | Std Dev: 0.033
# USL: 2.200 | LSL: 1.800
# UCL: 2.134 | LCL: 1.963
# Cp: 2.035 | Cpk: 1.539
# Sigma Level (≈ Cpk × 3): 4.618
# Risk Level: Acceptable
# Last Sigma Level: 4.638
# Data source: current(49) from 20251007-20251014
# OOC points: None
# --- 5w1.5BH MesaBOEWidth_2in Hancheng1 (I-MR SPC) ---
# Mean: 4.312 | Std Dev: 0.035
# USL: 4.450 | LSL: 4.150
# UCL: 4.444 | LCL: 4.156
# Cp: 1.416 | Cpk: 1.298
# Sigma Level (≈ Cpk × 3): 3.895
# Risk Level: Poor
# Last Sigma Level: 3.625
# Data source: current(49) from 20251007-20251014
# OOC points: None
# ===== RUNNING PRODUCT: 100G EML 475um =====
# no data points in the 100G EML 475um final thickness Hancheng1
# no data points in the 100G EML 475um Growth PL Hancheng1
# Accumulating '100G EML 475um | 100G EML 475um Mesa etch width Hancheng1': current(3) + history(5) = 8/20 points. No chart yet.
#
# ===== RUNNING PRODUCT: 25G RWG 175 um =====
# no data points in the 25G RWG 175um final thickness Hancheng1
# no data points in the 25G RWG 175um Growth PL Hancheng1
#
# --- 25G RWG 175um Mesa etch width Hancheng1 (I-MR SPC) ---
# Mean: 1.557 | Std Dev: 0.038
# USL: 1.700 | LSL: 1.460
# UCL: 1.695 | LCL: 1.465
# UAL: 1.660 | LAL: 1.500
# Cp: 1.041 | Cpk: 0.839
# Sigma Level (≈ Cpk × 3): 2.517
# Risk Level: High risk
# Last Sigma Level: 3.237
# Data source: memory(13) from 20250916-20250923 | current(7) from 20251007-20251014
# OOC points: None
